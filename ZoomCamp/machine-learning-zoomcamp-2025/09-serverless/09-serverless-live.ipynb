# %%
# !wget https://github.com/DataTalksClub/machine-learning-zoomcamp/releases/download/chapter7-model/xception_v4_large_08_0.894.h5 -O ./data/clothing-model.h5

# I coudn't use the model abouve so i taked the source code from it and train in the local machine
# Out:
# --2025-11-23 11:19:32--  https://github.com/DataTalksClub/machine-learning-zoomcamp/releases/download/chapter7-model/xception_v4_large_08_0.894.h5
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python -V
# Out:
# Python 3.11.14

# %%
import tensorflow as tf
from tensorflow import keras

tf.__version__
# Out:
# 2025-11-23 12:11:41.438511: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# '2.20.0'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
tf.config.optimizer.set_jit(False)

# %%
# List all GPUs with detailed info
gpus = tf.config.experimental.list_physical_devices('GPU')
for i, gpu in enumerate(gpus):
    print(f"GPU {i}: {gpu}")
# Out:
# GPU 0: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9750974084719301133
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1253834752
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11192010333804609211
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:08:00.0, compute capability: 8.9"
# xla_global_id: 416903419
# ]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763892705.535611   13670 gpu_device.cc:2020] Created device /device:GPU:0 with 1195 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:08:00.0, compute capability: 8.9

# %%
model = keras.models.load_model('xception_v4_large_04_0.897.h5')
# Out:
# I0000 00:00:1763892765.653761   13670 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1195 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:08:00.0, compute capability: 8.9
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# !wget http://bit.ly/mlbookcamp-pants -O pants.jpg
# Out:
# --2025-11-23 12:13:20--  http://bit.ly/mlbookcamp-pants
# Resolving bit.ly (bit.ly)... 67.199.248.11, 67.199.248.10
# Connecting to bit.ly (bit.ly)|67.199.248.11|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://raw.githubusercontent.com/alexeygrigorev/clothing-dataset-small/master/test/pants/4aabd82c-82e1-4181-a84d-d0c6e550d26d.jpg [following]
# --2025-11-23 12:13:20--  https://raw.githubusercontent.com/alexeygrigorev/clothing-dataset-small/master/test/pants/4aabd82c-82e1-4181-a84d-d0c6e550d26d.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23048 (23K) [image/jpeg]
# Saving to: ‘pants.jpg’
#
# pants.jpg           100%[===================>]  22.51K  --.-KB/s    in 0.007s
#
# ...
